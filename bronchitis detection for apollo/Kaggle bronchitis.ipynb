# %%
# organize imports
import os
import glob
import datetime
import pandas as pd
from shutil import copyfile

# %%
train_df = pd.read_csv("E:\IIITH AIML\week 13\Train_Labels.csv")
train_dict = {}
for i in train_df.values:
    train_dict[i[0]] = i[1]

# %%
print ("[INFO] program started on - " + str(datetime.datetime.now))

# get the input and output path
input_path  = "E:/IIITH AIML/week 13/Train_Images-002/Train_Images"
output_path = "E:/IIITH AIML/week 13/dataset/train"

# get the class label limit
class_limit = 2

# take all the images from the dataset
image_paths = glob.glob(input_path + "\\*.png")

class_names = ["0", "1"]

os.chdir(output_path)

#for x in range(1, class_limit+1):
#    os.system("mkdir " + class_names[label])
    
for image_path in image_paths[0:len(train_dict)]:
    original_path = image_path
    image_path = image_path.split("\\")
    image_path = image_path[len(image_path)-1]
    cur_path = output_path + "\\" + str(train_dict[image_path[:-4]]) + "\\"
    print(original_path)
    print(cur_path)
    print(image_path)
    print("----------------------------------------------------")
    src = original_path
    dest = cur_path + image_path
    copyfile(src, dest)
    #os.system("copy " + original_path + " " + cur_path + image_path)

# print end time
print ("[INFO] program ended on - " + str(datetime.datetime.now))
# Out:
# [INFO] program started on - <built-in method now of type object at 0x000000001E26C9D0>
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0002.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0002.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0005.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0005.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0006.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0006.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0007.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0007.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0008.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0008.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0009.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0009.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0010.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0010.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0011.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0011.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0012.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0012.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0013.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0013.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0014.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0014.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0015.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0015.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0016.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0016.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0017.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0017.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0018.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0018.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0019.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0019.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0021.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0021.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0023.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0023.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0025.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0025.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0027.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0027.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0028.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0028.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0031.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0031.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0032.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0032.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0033.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0033.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0036.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0036.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0038.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0038.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0039.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0039.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0040.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0040.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0043.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0043.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0044.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0044.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0045.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0045.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0046.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0046.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0048.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0048.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0049.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0049.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0050.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0050.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0051.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0051.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0053.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0053.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0054.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0054.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0055.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0055.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0056.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0056.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0057.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0057.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0058.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0058.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0059.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0059.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0060.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0060.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0061.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0061.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0062.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0062.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0063.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0063.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0064.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0064.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0065.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0065.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0066.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0066.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0067.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0067.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0069.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0069.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0072.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0072.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0073.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0073.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0074.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0074.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0075.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0075.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0076.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0076.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0077.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0077.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0078.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0078.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0079.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0079.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0080.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0080.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0081.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0081.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0082.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0082.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0084.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0084.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0085.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0085.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0086.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0086.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0087.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0087.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0088.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0088.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0089.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0089.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0090.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0090.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0091.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0091.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0092.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0092.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0093.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0093.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0094.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0094.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0095.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0095.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0097.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0097.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0098.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0098.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0099.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0099.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0102.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0102.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0103.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0103.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0104.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0104.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0105.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0105.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0106.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0106.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0107.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0107.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0108.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0108.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0109.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0109.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0112.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0112.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0113.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0113.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0115.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0115.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0116.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0116.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0117.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0117.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0118.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0118.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0119.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0119.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0120.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0120.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0122.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0122.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0123.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0123.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0124.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0124.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0125.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0125.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0127.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0127.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0128.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0128.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0129.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0129.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0130.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0130.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0132.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0132.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0133.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0133.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0135.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0135.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0136.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0136.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0138.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0138.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0139.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0139.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0140.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0140.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0141.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0141.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0142.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0142.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0144.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0144.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0147.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0147.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0149.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0149.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0150.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0150.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0151.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0151.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0152.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0152.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0153.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0153.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0154.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0154.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0155.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0155.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0156.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0156.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0158.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0158.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0160.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0160.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0161.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0161.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0162.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0162.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0163.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0163.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0164.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0164.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0165.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0165.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0166.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0166.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0167.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0167.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0168.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0168.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0169.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0169.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_0171.png
# E:/IIITH AIML/week 13/dataset/train\0\
# CR_0171.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\CR_
png
# E:/IIITH AIML/week 13/dataset/train\0\
# MR_0097.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0099.png
# E:/IIITH AIML/week 13/dataset/train\0\
# MR_0099.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0100.png
# E:/IIITH AIML/week 13/dataset/train\0\
# MR_0100.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0102.png
# E:/IIITH AIML/week 13/dataset/train\0\
# MR_0102.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0103.png
# E:/IIITH AIML/week 13/dataset/train\0\
# MR_0103.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0104.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0104.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0113.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0113.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0117.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0117.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0141.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0141.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0142.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0142.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0144.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0144.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0150.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0150.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0162.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0162.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0166.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0166.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0173.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0173.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0182.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0182.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0188.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0188.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0194.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0194.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0195.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0195.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0196.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0196.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0213.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0213.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0218.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0218.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0223.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0223.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0243.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0243.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0254.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0254.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0255.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0255.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0258.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0258.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0264.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0264.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0266.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0266.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0282.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0282.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0289.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0289.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0294.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0294.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0301.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0301.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0309.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0309.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0311.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0311.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0313.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0313.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0316.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0316.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0331.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0331.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0334.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0334.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0350.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0350.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0354.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0354.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0362.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0362.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0367.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0367.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0375.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0375.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0387.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0387.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0390.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0390.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0393.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0393.png
# ----------------------------------------------------
# E:/IIITH AIML/week 13/Train_Images-002/Train_Images\MR_0399.png
# E:/IIITH AIML/week 13/dataset/train\1\
# MR_0399.png
# ----------------------------------------------------
# [INFO] program ended on - <built-in method now of type object at 0x000000001E26C9D0>

# %%
# !conda install opencv
# Out:
# Solving environment: ...working...
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2018.03.07-0, anaconda::certifi-2018.4.16-py27_0, anaconda::openssl-1.0.2o-h2c51139_0
#   - anaconda::ca-certificates-2018.03.07-0, anaconda::openssl-1.0.2o-h2c51139_0, defaults::certifi-2018.4.16-py27_0
#   - anaconda::ca-certificates-2018.03.07-0, anaconda::certifi-2018.4.16-py27_0, defaults::openssl-1.0.2o-h2c51139_0
#   - anaconda::ca-certificates-2018.03.07-0, defaults::certifi-2018.4.16-py27_0, defaults::openssl-1.0.2o-h2c51139_0
#   - anaconda::certifi-2018.4.16-py27_0, defaults::ca-certificates-2018.03.07-0, defaults::openssl-1.0.2o-h2c51139_0
#   - defaults::ca-certificates-2018.03.07-0, defaults::certifi-2018.4.16-py27_0, defaults::openssl-1.0.2o-h2c51139_0
#   - anaconda::certifi-2018.4.16-py27_0, anaconda::openssl-1.0.2o-h2c51139_0, defaults::ca-certificates-2018.03.07-0
#   - anaconda::openssl-1.0.2o-h2c51139_0, defaults::ca-certificates-2018.03.07-0, defaults::certifi-2018.4.16-py27_0done
#
# # All requested packages already installed.

# %%
import sys
sys.path.append('C:/Users/sravyay/Anaconda2/Lib/site-packages/')
#sys.path.append('C:/Program Files/Anaconda3/Lib/site-packages/')

# %%
# filter warnings
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# keras imports
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.applications.vgg19 import VGG19, preprocess_input
from keras.applications.xception import Xception, preprocess_input
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.applications.mobilenet import MobileNet, preprocess_input
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.preprocessing import image
from keras.models import Model
from keras.models import model_from_json
from keras.layers import Input

# other imports
from sklearn.preprocessing import LabelEncoder
import numpy as np
import glob
import cv2
import h5py
import os
import json
import datetime
import time

# load the user configs
with open('conf/conf.json') as f:    
	config = json.load(f)

# config variables
model_name 		= config["model"]
weights 		= config["weights"]
include_top 	= config["include_top"]
train_path 		= config["train_path"]
features_path 	= config["features_path"]
labels_path 	= config["labels_path"]
test_size 		= config["test_size"]
results 		= config["results"]
model_path 		= config["model_path"]

# start time
print ("[STATUS] start time - {}".format(datetime.datetime.now().strftime("%Y-%m-%d %H:%M")))
start = time.time()

# create the pretrained models
# check for pretrained weight usage or not
# check for top layers to be included or not
if model_name == "vgg16":
	base_model = VGG16(weights=weights)
	model = Model(input=base_model.input, output=base_model.get_layer('fc1').output)
	image_size = (224, 224)
elif model_name == "vgg19":
	base_model = VGG19(weights=weights)
	model = Model(input=base_model.input, output=base_model.get_layer('fc1').output)
	image_size = (224, 224)
elif model_name == "resnet50":
	base_model = ResNet50(weights=weights)
	model = Model(input=base_model.input, output=base_model.get_layer('flatten').output)
	image_size = (224, 224)
elif model_name == "inceptionv3":
	base_model = InceptionV3(include_top=include_top, weights=weights, input_tensor=Input(shape=(299,299,3)))
	model = Model(input=base_model.input, output=base_model.get_layer('custom').output)
	image_size = (299, 299)
elif model_name == "inceptionresnetv2":
	base_model = InceptionResNetV2(include_top=include_top, weights=weights, input_tensor=Input(shape=(299,299,3)))
	model = Model(input=base_model.input, output=base_model.get_layer('custom').output)
	image_size = (299, 299)
elif model_name == "mobilenet":
	base_model = MobileNet(include_top=include_top, weights=weights, input_tensor=Input(shape=(224,224,3)), input_shape=(224,224,3))
	model = Model(input=base_model.input, output=base_model.get_layer('custom').output)
	image_size = (224, 224)
elif model_name == "xception":
	base_model = Xception(weights=weights)
	model = Model(input=base_model.input, output=base_model.get_layer('avg_pool').output)
	image_size = (299, 299)
else:
	base_model = None

print ("[INFO] successfully loaded base model and model...")

# path to training dataset
train_labels = os.listdir(train_path)

# encode the labels
print ("[INFO] encoding labels...")
le = LabelEncoder()
le.fit([tl for tl in train_labels])

# variables to hold features and labels
features = []
labels   = []

# loop over all the labels in the folder
count = 1
for i, label in enumerate(train_labels):
	cur_path = train_path + "/" + label
	count = 1
	for image_path in glob.glob(cur_path + "/*.png"):
		img = image.load_img(image_path, target_size=image_size)
		x = image.img_to_array(img)
		x = np.expand_dims(x, axis=0)
		x = preprocess_input(x)
		feature = model.predict(x)
		flat = feature.flatten()
		features.append(flat)
		labels.append(label)
		print ("[INFO] processed - " + str(count))
		count += 1
	print ("[INFO] completed label - " + label)

# encode the labels using LabelEncoder
le = LabelEncoder()
le_labels = le.fit_transform(labels)

# get the shape of training labels
print ("[STATUS] training labels: {}".format(le_labels))
print ("[STATUS] training labels shape: {}".format(le_labels.shape))

# save features and labels
h5f_data = h5py.File(features_path, 'w')
h5f_data.create_dataset('dataset_1', data=np.array(features))

h5f_label = h5py.File(labels_path, 'w')
h5f_label.create_dataset('dataset_1', data=np.array(le_labels))

h5f_data.close()
h5f_label.close()

# save model and weights
model_json = model.to_json()
with open(model_path + str(test_size) + ".json", "w") as json_file:
	json_file.write(model_json)

# save weights
model.save_weights(model_path + str(test_size) + ".h5")
print("[STATUS] saved model and weights to disk..")

print ("[STATUS] features and labels saved..")

# end time
end = time.time()
print ("[STATUS] end time - {}".format(datetime.datetime.now().strftime("%Y-%m-%d %H:%M")))
# Out:
# Using TensorFlow backend.
# ImportErrorTraceback (most recent call last)
# <ipython-input-7-27a45c8fbb1c> in <module>()
#       4
#       5 # keras imports
# ----> 6 from keras.applications.vgg16 import VGG16, preprocess_input
#       7 from keras.applications.vgg19 import VGG19, preprocess_input
#       8 from keras.applications.xception import Xception, preprocess_input
#
# C:\Users\sravyay\Anaconda2\Lib\site-packages\keras\__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# C:\Users\sravyay\Anaconda2\Lib\site-packages\keras\utils\__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# C:\Users\sravyay\Anaconda2\Lib\site-packages\keras\utils\conv_utils.py in <module>()
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# C:\Users\sravyay\Anaconda2\Lib\site-packages\keras\backend\__init__.py in <module>()
#      82 elif _BACKEND == 'tensorflow':
#      83     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 84     from .tensorflow_backend import *
#      85 else:
#      86     raise ValueError('Unknown backend: ' + str(_BACKEND))
#
# C:\Users\sravyay\Anaconda2\Lib\site-packages\keras\backend\tensorflow_backend.py in <module>()
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.training import moving_averages
#       7 from tensorflow.python.ops import tensor_array_ops
#
# ImportError: No module named tensorflow

# %%
# organize imports
from __future__ import print_function

from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import numpy as np
import h5py
import os
import json
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# load the user configs
with open('conf/conf.json') as f:    
	config = json.load(f)

# config variables
test_size 		= config["test_size"]
seed 			= config["seed"]
features_path 	= config["features_path"]
labels_path 	= config["labels_path"]
results 		= config["results"]
classifier_path = config["classifier_path"]
train_path 		= config["train_path"]
num_classes 	= config["num_classes"]
classifier_path = config["classifier_path"]

# import features and labels
h5f_data  = h5py.File(features_path, 'r')
h5f_label = h5py.File(labels_path, 'r')

features_string = h5f_data['dataset_1']
labels_string   = h5f_label['dataset_1']

features = np.array(features_string)
labels   = np.array(labels_string)

h5f_data.close()
h5f_label.close()

# verify the shape of features and labels
print ("[INFO] features shape: {}".format(features.shape))
print ("[INFO] labels shape: {}".format(labels.shape))

print ("[INFO] training started...")
# split the training and testing data
(trainData, testData, trainLabels, testLabels) = train_test_split(np.array(features),
                                                                  np.array(labels),
                                                                  test_size=test_size,
                                                                  random_state=seed)

print ("[INFO] splitted train and test data...")
print ("[INFO] train data  : {}".format(trainData.shape))
print ("[INFO] test data   : {}".format(testData.shape))
print ("[INFO] train labels: {}".format(trainLabels.shape))
print ("[INFO] test labels : {}".format(testLabels.shape))

# use logistic regression as the model
print ("[INFO] creating model...")
model = LogisticRegression(random_state=seed)
model.fit(trainData, trainLabels)

# use rank-1 and rank-5 predictions
print ("[INFO] evaluating model...")
f = open(results, "w")
rank_1 = 0
rank_5 = 0

# loop over test data
for (label, features) in zip(testLabels, testData):
	# predict the probability of each class label and
	# take the top-5 class labels
	predictions = model.predict_proba(np.atleast_2d(features))[0]
	predictions = np.argsort(predictions)[::-1][:5]

	# rank-1 prediction increment
	if label == predictions[0]:
		rank_1 += 1

	# rank-5 prediction increment
	if label in predictions:
		rank_5 += 1

# convert accuracies to percentages
rank_1 = (rank_1 / float(len(testLabels))) * 100
rank_5 = (rank_5 / float(len(testLabels))) * 100

# write the accuracies to file
f.write("Rank-1: {:.2f}%\n".format(rank_1))
f.write("Rank-5: {:.2f}%\n\n".format(rank_5))

# evaluate the model of test data
preds = model.predict(testData)

# write the classification report to file
f.write("{}\n".format(classification_report(testLabels, preds)))
f.close()

# dump classifier to file
print ("[INFO] saving model...")
pickle.dump(model, open(classifier_path, 'wb'))

# display the confusion matrix
print ("[INFO] confusion matrix")

# get the list of training lables
labels = sorted(list(os.listdir(train_path)))

# plot the confusion matrix
cm = confusion_matrix(testLabels, preds)
sns.heatmap(cm,
            annot=True,
            cmap="Set2")
plt.show()
